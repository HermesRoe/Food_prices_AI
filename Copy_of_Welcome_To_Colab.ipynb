# %% [markdown]
# <a href="https://colab.research.google.com/github/HermesRoe/Food_prices_AI/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Remove the HXL tags (Row 0)
df = df.drop(df.index[0])

# 2. Filter for India (if not already filtered) and standardize
india_df = df[df['admin1'] == 'Delhi'].copy() # Focus on Delhi for best accuracy

# 3. Clean Units and Types
india_df['price'] = pd.to_numeric(india_df['price'], errors='coerce')
india_df['date'] = pd.to_datetime(india_df['date'])
india_df = india_df[india_df['unit'] == 'KG'] # Essential for that 0.13 error margin!

# 4. Create Time Features
india_df['year'] = india_df['date'].dt.year
india_df['month'] = india_df['date'].dt.month

print("Cleanup successful! Data is standard and ready.")
india_df.head()
# Out:
# Cleanup successful! Data is standard and ready.
#          date admin1 admin2 market   latitude  longitude            category  \
# 1  1994-01-15  Delhi  Delhi  Delhi  28.666667  77.216667  cereals and tubers
# 2  1994-01-15  Delhi  Delhi  Delhi  28.666667  77.216667  cereals and tubers
# 3  1994-01-15  Delhi  Delhi  Delhi  28.666667  77.216667  miscellaneous food
# 4  1994-01-15  Delhi  Delhi  Delhi  28.666667  77.216667        oil and fats
# 34 1994-02-15  Delhi  Delhi  Delhi  28.666667  77.216667  cereals and tubers
#
#         commodity unit priceflag pricetype currency  price usdprice  year  \
# 1            Rice   KG    actual    Retail      INR    8.0   0.2545  1994
# 2           Wheat   KG    actual    Retail      INR    5.0    0.159  1994
# 3           Sugar   KG    actual    Retail      INR   13.5   0.4294  1994
# 4   Oil (mustard)   KG    actual    Retail      INR   31.0    0.986  1994
# 34           Rice   KG    actual    Retail      INR    8.0   0.2545  1994
#
#     month
# 1       1
# 2       1
# 3       1
# 4       1
# 34      2
